# %%
import pandas as pd
df = pd.read_csv("Pokemon(4).csv");
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df[['Name','Type 1']]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
df.sort_values(by=['Speed'], ascending=False)
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 431  386          DeoxysSpeed Forme  Psychic     NaN    600   50      95
# 315  291                    Ninjask      Bug  Flying    456   61      90
# 428  386         DeoxysNormal Forme  Psychic     NaN    600   50     150
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615   80     135
# 71    65      AlakazamMega Alakazam  Psychic     NaN    590   55      50
# ..   ...                        ...      ...     ...    ...  ...     ...
# 658  597                  Ferroseed    Grass   Steel    305   44      50
# 486  438                     Bonsly     Rock     NaN    290   50      80
# 359  328                   Trapinch   Ground     NaN    290   45     100
# 230  213                    Shuckle      Bug    Rock    505   20      10
# 495  446                   Munchlax   Normal     NaN    390  135      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.set_index('Generation', inplace=True)
df
# Out:
#               #                   Name   Type 1  Type 2  Total  HP  Attack  \
# Generation
# 1             1              Bulbasaur    Grass  Poison    318  45      49
# 1             2                Ivysaur    Grass  Poison    405  60      62
# 1             3               Venusaur    Grass  Poison    525  80      82
# 1             3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 1             4             Charmander     Fire     NaN    309  39      52
# ...         ...                    ...      ...     ...    ...  ..     ...
# 6           719                Diancie     Rock   Fairy    600  50     100
# 6           719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 6           720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 6           720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 6           721              Volcanion     Fire   Water    600  80     110
#
#             Defense  Sp. Atk  Sp. Def  Speed  Legendary
# ...

# %%
df[df['Legendary']==True]
# Out:
#               #                 Name    Type 1    Type 2  Total   HP  Attack  \
# Generation
# 1           144             Articuno       Ice    Flying    580   90      85
# 1           145               Zapdos  Electric    Flying    580   90      90
# 1           146              Moltres      Fire    Flying    580   90     100
# 1           150               Mewtwo   Psychic       NaN    680  106     110
# 1           150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ...         ...                  ...       ...       ...    ...  ...     ...
# 6           719              Diancie      Rock     Fairy    600   50     100
# 6           719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 6           720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 6           720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 6           721            Volcanion      Fire     Water    600   80     110
#
# ...

# %%
df.reset_index(inplace=True)
df.set_index('Type 2',inplace=True)
df
# Out:
#         Generation    #                   Name   Type 1  Total  HP  Attack  \
# Type 2
# Poison           1    1              Bulbasaur    Grass    318  45      49
# Poison           1    2                Ivysaur    Grass    405  60      62
# Poison           1    3               Venusaur    Grass    525  80      82
# Poison           1    3  VenusaurMega Venusaur    Grass    625  80     100
# NaN              1    4             Charmander     Fire    309  39      52
# ...            ...  ...                    ...      ...    ...  ..     ...
# Fairy            6  719                Diancie     Rock    600  50     100
# Fairy            6  719    DiancieMega Diancie     Rock    700  50     160
# Ghost            6  720    HoopaHoopa Confined  Psychic    600  80     110
# Dark             6  720     HoopaHoopa Unbound  Psychic    680  80     160
# Water            6  721              Volcanion     Fire    600  80     110
#
#         Defense  Sp. Atk  Sp. Def  Speed  Legendary
# ...

# %%
df[df['Attack'] > 130].sort_values(by=['Attack'], ascending=False)
# Out:
#           Generation    #                       Name    Type 1  Total   HP  \
# Type 2
# Fighting           1  150        MewtwoMega Mewtwo X   Psychic    780  106
# Fighting           2  214    HeracrossMega Heracross       Bug    600   80
# Flying             3  384      RayquazaMega Rayquaza    Dragon    780  105
# NaN                3  386         DeoxysAttack Forme   Psychic    600   50
# Fire               3  383      GroudonPrimal Groudon    Ground    770  100
# Ice                5  646         KyuremBlack Kyurem    Dragon    700  125
# Ground             4  445      GarchompMega Garchomp    Dragon    700  108
# NaN                3  354        BanetteMega Banette     Ghost    555   64
# Fighting           4  475        GalladeMega Gallade   Psychic    618   68
# NaN                4  409                  Rampardos      Rock    495   97
# Dark               2  248    TyranitarMega Tyranitar      Rock    700  100
# ...

# %%
df.sort_values(by=['Sp. Atk'], ascending=False)
# Out:
#         Generation    #                   Name   Type 1  Total   HP  Attack  \
# Type 2
# NaN              1  150    MewtwoMega Mewtwo Y  Psychic    780  106     150
# NaN              3  382    KyogrePrimal Kyogre    Water    770  100     150
# NaN              3  386     DeoxysAttack Forme  Psychic    600   50     180
# Flying           3  384  RayquazaMega Rayquaza   Dragon    780  105     180
# NaN              1   65  AlakazamMega Alakazam  Psychic    590   55      50
# ...            ...  ...                    ...      ...    ...  ...     ...
# NaN              5  554               Darumaka     Fire    315   70      90
# Poison           1   15  BeedrillMega Beedrill      Bug    495   65     150
# Rock             2  213                Shuckle      Bug    505   20      10
# NaN              4  438                 Bonsly     Rock    290   50      80
# NaN              3  349                 Feebas    Water    200   20      15
#
# ...
